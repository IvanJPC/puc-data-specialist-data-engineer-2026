# %%
# %sql
CREATE VOLUME IF NOT EXISTS puc_data_specialist_de_2026_09.`00-raw`.amazon_sales_raw

# %%
# Install kaggle API (only needed once)
# %pip install kaggle
dbutils.library.restartPython()

# %%
KAGGLE_API_TOKEN= ""
# --- Creating a folder with a date information to prevent overwriting ---
from datetime import datetime

timestamp = datetime.now().strftime("%YYYY-%mm-%dd")

volume_path = f"/Volumes/puc_data_specialist_de_2026_09/00-raw/amazon_sales_raw/{timestamp}"

# --- Configure Kaggle credentials ---
# Set your Kaggle username and API key here (from kaggle.com -> Account -> Create New Token)
import os
os.environ["KAGGLE_USERNAME"] = "YOUR_KAGGLE_USERNAME"
os.environ["KAGGLE_KEY"] = "YOUR_KAGGLE_KEY"

# --- Download dataset into the volume (no changes to files) ---
from kaggle import KaggleApi

api = KaggleApi()
api.authenticate()



api.dataset_download_files(
    "karkavelrajaj/amazon-sales-dataset",
    path=volume_path,
    unzip=True,        
    quiet=False,
)
